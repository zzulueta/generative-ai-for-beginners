# %%
from openai import AzureOpenAI
import json
import os
import time

from dotenv import load_dotenv
load_dotenv()

azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT")
azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT")
api_key=os.getenv("AZURE_OPENAI_KEY")

# Create an AzureOpenAI client
client = AzureOpenAI(
  azure_endpoint = azure_endpoint,
  api_key= api_key,
  api_version="2024-05-01-preview"
)
# Create a file
file = client.files.create(
  file=open("./data/bigfootsightings.csv", "rb"),
  purpose='assistants'
)

# Create an assistant
assistant = client.beta.assistants.create(
  model=azure_deployment, # replace with model deployment name.
  name="codeexecuter"
  instructions="""You are an assistant answering questions about bigfootsightings dataset.""",
  tools=[{"type":"code_interpreter"}],
  tool_resources={"code_interpreter":{"file_ids":[file.id]}},
  temperature=1,
  top_p=1
)

# Create a thread
thread = client.beta.threads.create()

# %%
PROMPT_SUFFIX = """
- **ALWAYS** before giving the Final Answer, try another method.
Then reflect on the answers of the two methods you did and ask yourself
if it answers correctly the original question.
If you are not sure, try another method.
- If the methods tried do not give the same result,reflect and
try again until you have two methods that have the same result.
- If you still cannot arrive to a consistent result, say that
you are not sure of the answer.
- If you are sure of the correct answer, create a beautiful
and thorough response using Markdown.
- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,
ONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.
- **ALWAYS**, as part of your "Final Answer", explain how you got
to the answer on a section that starts with: "\n\nExplanation:\n".
In the explanation, mention the column names that you used to get
to the final answer and provide the python code you used.

"""

# %%
user_question ="""If 1 row in the dataset is 1 sighting, what's our total sightings
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )
if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)

# Print the assistant response
content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# SyncCursorPage[Message](data=[Message(id='msg_uwYaEzNojTAGSyvgqHludlHZ', assistant_id='asst_6Tn9P9XnJ6lvG5PBzDpOMgAO', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="We have two consistent results:\n\n- Method 1 (using `shape`): 5021 sightings\n- Method 3 (using `len` function): 5021 sightings\n\nBoth methods correctly consider the total number of rows in the dataset, regardless of missing values in the columns, and both report 5021 sightings.\n\n## Explanation:\nThe total number of sightings in the dataset was calculated using the `shape` attribute and the `len()` function, both of which confirmed that there are 5021 rows in the dataset, meaning there are 5021 sightings. \n\nHere's the python code used:\n```python\nimport pandas as pd\n\n# Load the dataset\nfile_path = '/mnt/data/assistant-jTs5aSPMjwfDUPeK7IUvvbIi'\ndata = pd.read_csv(file_path)\n\n# Calculate the total number of sightings using the shape attribute\ntotal_sightings = data.shape[0]\n\n# Calculate the total number of sightings using the len() function\ntotal_sightings_len = len(data)\n```\n\nThus, the total number of sightings in the dataset is **5021**."), type='text')], created_at=1731421733, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_UkGIKauiSBbFJH1ahdBaGfSs', status=None, thread_id='thread_d95QnLipg0jFPHQwFo3i4LPn'), Message(id='msg_ira9q7cphF49dhbbV4KIjVE9', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='\n- **ALWAYS** before giving the Final Answer, try another method.\nThen reflect on the answers of the two methods you did and ask yourself\nif it answers correctly the original question.\nIf you are not sure, try another method.\n- If the methods tried do not give the same result,reflect and\ntry again until you have two methods that have the same result.\n- If you still cannot arrive to a consistent result, say that\nyou are not sure of the answer.\n- If you are sure of the correct answer, create a beautiful\nand thorough response using Markdown.\n- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,\nONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.\n- **ALWAYS**, as part of your "Final Answer", explain how you got\nto the answer on a section that starts with: "\n\nExplanation:\n".\nIn the explanation, mention the column names that you used to get\nto the final answer and provide the python code you used.\n\nIf 1 row in the dataset is 1 sighting, what\'s our total sightings\n'), type='text')], created_at=1731421729, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_d95QnLipg0jFPHQwFo3i4LPn'), Message(id='msg_8ztu0LFvgPJDj9bNxDH4aLpK', assistant_id='asst_6Tn9P9XnJ6lvG5PBzDpOMgAO', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="The dataset contains a significant number of missing values across several columns, which likely explains the discrepancy between the two methods.\n\nMethod 1, which uses the shape attribute, correctly counts the number of rows regardless of missing values in the columns. Method 2's count function, however, only counts non-null entries in the first column, which results in the lower count.\n\nThus, the accurate total number of sightings is given by the shape attribute method.\n\n## Explanation:\nThe total number of sightings was calculated using the shape attribute of the pandas DataFrame, which gives the number of rows in the dataset. This method accounts for all rows, including those with missing values in some columns, providing us with 5021 sightings. The dataset contains various missing values across multiple columns, which influenced the result of the count function.\n\nHere's the python code used:\n```python\nimport pandas as pd\n\n# Load the dataset\nfile_path = '/mnt/data/assistant-jTs5aSPMjwfDUPeK7IUv ...
# We have two consistent results:
#
# - Method 1 (using `shape`): 5021 sightings
# - Method 3 (using `len` function): 5021 sightings
#
# Both methods correctly consider the total number of rows in the dataset, regardless of missing values in the columns, and both report 5021 sightings.
#
# ## Explanation:
# The total number of sightings in the dataset was calculated using the `shape` attribute and the `len()` function, both of which confirmed that there are 5021 rows in the dataset, meaning there are 5021 sightings.
#
# Here's the python code used:
# ```python
# import pandas as pd
#
# # Load the dataset
# file_path = '/mnt/data/assistant-jTs5aSPMjwfDUPeK7IUvvbIi'
# data = pd.read_csv(file_path)
#
# # Calculate the total number of sightings using the shape attribute
# total_sightings = data.shape[0]
#
# # Calculate the total number of sightings using the len() function
# total_sightings_len = len(data)
# ```
#
# Thus, the total number of sightings in the dataset is **5021**.

# %%
user_question ="""Which state has the most sightings? Provide the number of sightings in that state
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)


content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# SyncCursorPage[Message](data=[Message(id='msg_3xRqQEeaaSQ9DZs4nXcJ8YX6', assistant_id='asst_6Tn9P9XnJ6lvG5PBzDpOMgAO', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="Both methods confirm that Washington has the most sightings with a total of 601 sightings.\n\n## Explanation:\nThe state with the most sightings was identified using two different methods: the `value_counts` method and grouping the data by state and calculating the size of each group. Both methods resulted in Washington as the state with the most sightings, with a total of 601 sightings.\n\nHere's the python code used:\n```python\nimport pandas as pd\n\n# Load the dataset\nfile_path = '/mnt/data/assistant-jTs5aSPMjwfDUPeK7IUvvbIi'\ndata = pd.read_csv(file_path)\n\n# Method 1: Identify the state with the most sightings using value_counts\nstate_sightings = data['state'].value_counts()\nmost_sightings_state = state_sightings.idxmax()\nmost_sightings_count = state_sightings.max()\n\n# Method 2: Group the data by state and count the number of sightings in each state\nstate_sightings_grouped = data.groupby('state').size()\nmost_sightings_state_grouped = state_sightings_grouped.idxmax()\nmost_sightings_count_grouped = state_sightings_grouped.max()\n```\n\nThus, the state with the most sightings is **Washington**, with a total of **601** sightings."), type='text')], created_at=1731421924, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_VD0Oc5IaIfzUEWx64p3Nk2wR', status=None, thread_id='thread_d95QnLipg0jFPHQwFo3i4LPn'), Message(id='msg_dr7tj6S5YKA2muOMBancMC2T', assistant_id='asst_6Tn9P9XnJ6lvG5PBzDpOMgAO', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="Let's validate the result using another method to ensure that Washington is indeed the state with the most sightings.\n\nMethod 2: Group the data by state and count the number of sightings in each state.\n\n"), type='text')], created_at=1731421920, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_VD0Oc5IaIfzUEWx64p3Nk2wR', status=None, thread_id='thread_d95QnLipg0jFPHQwFo3i4LPn'), Message(id='msg_BAkztVJCzXYgs8yB7OHuMn5u', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='\n- **ALWAYS** before giving the Final Answer, try another method.\nThen reflect on the answers of the two methods you did and ask yourself\nif it answers correctly the original question.\nIf you are not sure, try another method.\n- If the methods tried do not give the same result,reflect and\ntry again until you have two methods that have the same result.\n- If you still cannot arrive to a consistent result, say that\nyou are not sure of the answer.\n- If you are sure of the correct answer, create a beautiful\nand thorough response using Markdown.\n- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,\nONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.\n- **ALWAYS**, as part of your "Final Answer", explain how you got\nto the answer on a section that starts with: "\n\nExplanation:\n".\nIn the explanation, mention the column names that you used to get\nto the final answer and provide the python code you used.\n\nWhich state has the most sightings? Provide the number of sightings in that state\n'), type='text')], created_at=1731421915, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_d95QnLipg0jFPHQwFo3i4LPn'), Message(id='msg_uwYaEzNojTAGSyvgqHludlHZ', assistant_id='asst_6Tn9P9XnJ6lvG5PBzDpOMgAO', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="We have two consistent results:\n\n- Method 1 (using `shape`): 5021 sightings\n- Method 3 (using `len` function): 5021 sightings\n\nBoth methods correctly consider the total number of rows in  ...
# Both methods confirm that Washington has the most sightings with a total of 601 sightings.
#
# ## Explanation:
# The state with the most sightings was identified using two different methods: the `value_counts` method and grouping the data by state and calculating the size of each group. Both methods resulted in Washington as the state with the most sightings, with a total of 601 sightings.
#
# Here's the python code used:
# ```python
# import pandas as pd
#
# # Load the dataset
# file_path = '/mnt/data/assistant-jTs5aSPMjwfDUPeK7IUvvbIi'
# data = pd.read_csv(file_path)
#
# # Method 1: Identify the state with the most sightings using value_counts
# state_sightings = data['state'].value_counts()
# most_sightings_state = state_sightings.idxmax()
# most_sightings_count = state_sightings.max()
#
# # Method 2: Group the data by state and count the number of sightings in each state
# state_sightings_grouped = data.groupby('state').size()
# most_sightings_state_grouped = state_sightings_grouped.idxmax()
# most_sightings_count_grouped = state_sightings_grouped.max()
# ```
#
# Thus, the state with the most sightings is **Washington**, with a total of **601** sightings.

# %%
user_question ="""Which season has the most sightings?
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)


content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 user_question ="""Which season has the most sightings?
#       2 """
#       4 # Add a user question to the thread
# ----> 5 message = client.beta.threads.messages.create(
#       6   thread_id=thread.id,
#       7   role="user",
#       8   content=PROMPT_SUFFIX + user_question
#       9 )
#      11 # Run the thread
#      12 run = client.beta.threads.runs.create(
#      13   thread_id=thread.id,
#      14   assistant_id=assistant.id
#      15 )
#
# NameError: name 'client' is not defined

# %%
user_question ="""What are the top 10 years with the most sightings? Use the date column and get the year there.
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)


content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# SyncCursorPage[Message](data=[Message(id='msg_7sNlYwUdNl4ywzfMis46K5L7', assistant_id='asst_2l1ustJwnB2SyY8PwkNB9W9L', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="## Final Answer\n\nThe top 10 years with the most bigfoot sightings are as follows:\n\n1. 2004: 241 sightings\n2. 2005: 209 sightings\n3. 2006: 176 sightings\n4. 2003: 152 sightings\n5. 2000: 146 sightings\n6. 2007: 145 sightings\n7. 2008: 141 sightings\n8. 2012: 141 sightings\n9. 2001: 131 sightings\n10. 2011: 121 sightings\n\n---\n\n## Explanation\n\nTo get the years with the most sightings:\n\nWe first transformed the 'date' column into a datetime format. Then, we extracted the year and created a new 'year' column in the dataframe. \n\nSubsequently, we counted the number of sightings in each year. We used two methods to carry out these calculations:\n\n1. Method 1: Use the value_counts() function to tally the instances of each year, sort them in descending order, and pick the top 10.\n\n```python\ntop_10_years_with_most_sightings = data['year'].value_counts().nlargest(10)\n```\n\n2. Method 2: Group the dataframe by 'year' and count the number of sightings using the size() function. After that, sort the results in descending order and pick the top 10.\n\n```python\ntop_10_years_with_most_sightings_alternative = data.groupby('year').size().nlargest(10)\n```\n\nBoth methods yielded the same results, confirming that the answer is accurate."), type='text')], created_at=1728969057, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_YA1PMhL2nS4yowasu24g4zOh', status=None, thread_id='thread_7uT5DjV5QT14APgBT3XUZkMY'), Message(id='msg_53eOB0wloCZ0WOpq3pI841TG', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='\n- **ALWAYS** before giving the Final Answer, try another method.\nThen reflect on the answers of the two methods you did and ask yourself\nif it answers correctly the original question.\nIf you are not sure, try another method.\n- If the methods tried do not give the same result,reflect and\ntry again until you have two methods that have the same result.\n- If you still cannot arrive to a consistent result, say that\nyou are not sure of the answer.\n- If you are sure of the correct answer, create a beautiful\nand thorough response using Markdown.\n- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,\nONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.\n- **ALWAYS**, as part of your "Final Answer", explain how you got\nto the answer on a section that starts with: "\n\nExplanation:\n".\nIn the explanation, mention the column names that you used to get\nto the final answer and provide the python code you used.\n\nWhat are the top 10 years with the most sightings? Use the date column and get the year there.\n'), type='text')], created_at=1728969055, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_7uT5DjV5QT14APgBT3XUZkMY'), Message(id='msg_afo8rWqK2482B4qK0MQ4PzuS', assistant_id='asst_2l1ustJwnB2SyY8PwkNB9W9L', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="After reflecting on the results obtained from both methods, it can be seen that they are consistent and we have arrived at our final answer. The top 10 years with the most sightings are as follows:\n\n- 2004: 241 sightings\n- 2005: 209 sightings\n- 2006: 176 sightings\n- 2003: 152 sightings\n- 2000: 146 sightings\n- 2007: 145 sightings\n- 2008: 141 sightings\n- 2012: 141 sightings\n- 2001: 131 sightings\n- 2011: 121 sightings\n\n**Explanation:**\n\nFrom the 'date' column, the 'year' was extracted and stored in a new column called 'year'. The 'value_counts' function was then used to count the number of occurrences of each year, and the top 10 years with the most sightings were taken. The same result was ...
# ## Final Answer
#
# The top 10 years with the most bigfoot sightings are as follows:
#
# 1. 2004: 241 sightings
# 2. 2005: 209 sightings
# 3. 2006: 176 sightings
# 4. 2003: 152 sightings
# 5. 2000: 146 sightings
# 6. 2007: 145 sightings
# 7. 2008: 141 sightings
# 8. 2012: 141 sightings
# 9. 2001: 131 sightings
# 10. 2011: 121 sightings
#
# ---
#
# ## Explanation
#
# To get the years with the most sightings:
#
# We first transformed the 'date' column into a datetime format. Then, we extracted the year and created a new 'year' column in the dataframe.
#
# Subsequently, we counted the number of sightings in each year. We used two methods to carry out these calculations:
#
# 1. Method 1: Use the value_counts() function to tally the instances of each year, sort them in descending order, and pick the top 10.
#
# ```python
# top_10_years_with_most_sightings = data['year'].value_counts().nlargest(10)
# ```
#
# 2. Method 2: Group the dataframe by 'year' and count the number of sightings using the size() function. After that, sort the results in descending order and pick the top 10.
#
# ```python
# top_10_years_with_most_sightings_alternative = data.groupby('year').size().nlargest(10)
# ```
#
# Both methods yielded the same results, confirming that the answer is accurate.

# %%
user_question ="""How many sightings did we have for Washington state in the year 2000?
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)


content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# failed
# ### Mt. Mitchell Sighting in the Dataset
#
# There is one recorded Bigfoot sighting in the dataset which mentions Mt. Mitchell. Here are the details of that sighting:
#
# - **Observed:** "In early spring 1988, some friends of mine and I were hiking around Mt. Mitchell. We noticed deep impressions in the snow..."
# - **County:** Yancey County
# - **State:** North Carolina
# - **Season:** Spring
# - **Date:** March 15, 1988
# - **Classification:** Class B
#
# ### Explanation:
# To find out if there are any Bigfoot sightings observed at Mt. Mitchell, I checked for the occurrence of "Mt. Mitchell" in the "observed" column of the dataset. The steps taken are as follows:
#
# 1. Loaded the data and inspected the columns to understand its structure.
# 2. Filtered the dataset to locate rows where the "observed" column contains the text "Mt. Mitchell".
# 3. Verified the count and details of the sightings mentioning Mt. Mitchell.
#
# Here is the Python code used:
#
# ```python
# import pandas as pd
#
# # Load the dataframe from the uploaded file
# file_path = '/mnt/data/assistant-KTbs86aiQh7chrEjIa76W0aC'
# df = pd.read_csv(file_path)
#
# # Check for occurrences of 'Mt. Mitchell' in the 'observed' column
# mt_mitchell_sightings = df[df['observed'].str.contains('Mt. Mitchell', case=False, na=False)]
# mt_mitchell_sightings_count = mt_mitchell_sightings.shape[0]
#
# # Display the rows containing "Mt. Mitchell" in the "observed" column
# mt_mitchell_sightings
# ```
#
# Thus, there is a verified sighting observed at Mt. Mitchell mentioned in the data.

# %%
user_question ="""Using the "observed" column, are there any sightings observed at Mt. Mitchell?
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )
if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)

# Print the assistant response
content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)

# %% [markdown]
# # Delete Assistant

# %%
response = client.beta.assistants.delete(assistant.id)
