# %%
from openai import AzureOpenAI
import json
import os
import time

from dotenv import load_dotenv
load_dotenv()

azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT")
azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT")
api_key=os.getenv("AZURE_OPENAI_KEY")

# Create an AzureOpenAI client
client = AzureOpenAI(
  azure_endpoint = azure_endpoint,
  api_key= api_key,
  api_version="2024-05-01-preview"
)
# Create a file
file = client.files.create(
  file=open("./data/bigfootsightings.csv", "rb"),
  purpose='assistants'
)

# Create an assistant
assistant = client.beta.assistants.create(
  model=azure_deployment,
  name="bigfootsightings",
  instructions="""You are an assistant answering questions about bigfootsightings dataset.""",
  tools=[{"type":"code_interpreter"}],
  tool_resources={"code_interpreter":{"file_ids":[file.id]}},
  temperature=1,
  top_p=1,
  
)

# Create a thread
thread = client.beta.threads.create()

# %%
PROMPT_SUFFIX = """
- **ALWAYS** before giving the Final Answer, try another method.
Then reflect on the answers of the two methods you did and ask yourself
if it answers correctly the original question.
If you are not sure, try another method.
- If the methods tried do not give the same result,reflect and
try again until you have two methods that have the same result.
- If you still cannot arrive to a consistent result, say that
you are not sure of the answer.
- If you are sure of the correct answer, create a beautiful
and thorough response using Markdown.
- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,
ONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.
- **ALWAYS**, as part of your "Final Answer", explain how you got
to the answer on a section that starts with: "\n\nExplanation:\n".
In the explanation, mention the column names that you used to get
to the final answer and provide the python code you used.

"""

# %% [markdown]
# Questions:
# 1. If 1 row in the dataset is 1 sighthing, what's our total sightings?
# 2. Which state has the most sightings?
# 3. Which season has the most sightings?
# 4. What are the top 10 years with the most sightings?
# 5. How many sightings did we have for Washington state in the year 2000?
#
# Answers:
# 1. 5021
# 2. Washington (601)
# 3. Summer
# 4. 2004, 2005, 2006, 2003, 2000, 2007, 2008, 2012, 2001, 2011
# 5. 28

# %%
user_question ="""If 1 row in the dataset is 1 sighting, what's our total sightings
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )
if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)

# Print the assistant response
content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# SyncCursorPage[Message](data=[Message(id='msg_hTNTpBlEDW7OAeS5a4oxrKCG', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Both methods yield the same result, confirming the total number of bigfoot sightings in the dataset.\n\n### Final Answer:\n\nThe total number of bigfoot sightings in the dataset is **5021**.\n\n#### Explanation:\n- The dataset was loaded and examined to understand its structure, where each row represents a single sighting.\n- The total number of rows in the dataset was calculated using two methods:\n  1. Using `shape[0]` to get the total number of rows.\n  2. Using `len(index)` to get the total number of rows.\n\nBoth methods provided the same result of 5021 sightings.\n\n```python\n# Method 1: Using shape[0]\ntotal_sightings = bigfoot_sightings.shape[0]\n\n# Method 2: Using len(index)\ntotal_sightings_verification = len(bigfoot_sightings.index)\n```\n'), type='text')], created_at=1731715997, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_axucDOz5sL3FxPQp3CWEWBds', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_ENVTcMSzA7Hl2NLqTTDool4k', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="To verify the result, I will calculate the total number of sightings using another method by summing the occurrences after checking the index values.\n\nLet's perform the verification:"), type='text')], created_at=1731715994, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_axucDOz5sL3FxPQp3CWEWBds', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_JHtbmCjxAuyHB37upWBtjkUJ', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="The dataset has each row representing a single sighting. Therefore, the total number of sightings is equal to the number of rows in the dataset.\n\nLet's calculate the total number of rows to determine the total number of sightings."), type='text')], created_at=1731715991, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_axucDOz5sL3FxPQp3CWEWBds', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_tHzbjJSnTaAIcn9Iy8n0D7Sg', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="Let's first load the dataset, check the columns it contains, and then calculate the total number of sightings.\n\nI'll start by loading the dataset to examine its structure."), type='text')], created_at=1731715985, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_axucDOz5sL3FxPQp3CWEWBds', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_MrO3YJVNFJvLccWN3ufklpDR', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='\n- **ALWAYS** before giving the Final Answer, try another method.\nThen reflect on the answers of the two methods you did and ask yourself\nif it answers correctly the original question.\nIf you are not sure, try another method.\n- If the methods tried do not give the same result,reflect and\ntry again until you have two methods that have the same result.\n- If you still cannot arrive to a consistent result, say that\nyou are not sure of the answer.\n- If you are sure of the correct answer, create a beautiful\nand thorough response using Markdown.\n- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,\nONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.\n- **ALWAYS**, as part of your "Final Answer", explain how you got\nto the answer on a section that ...
# Both methods yield the same result, confirming the total number of bigfoot sightings in the dataset.
#
# ### Final Answer:
#
# The total number of bigfoot sightings in the dataset is **5021**.
#
# #### Explanation:
# - The dataset was loaded and examined to understand its structure, where each row represents a single sighting.
# - The total number of rows in the dataset was calculated using two methods:
#   1. Using `shape[0]` to get the total number of rows.
#   2. Using `len(index)` to get the total number of rows.
#
# Both methods provided the same result of 5021 sightings.
#
# ```python
# # Method 1: Using shape[0]
# total_sightings = bigfoot_sightings.shape[0]
#
# # Method 2: Using len(index)
# total_sightings_verification = len(bigfoot_sightings.index)
# ```

# %%
user_question ="""Which state has the most sightings? Provide the number of sightings in that state
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)


content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# SyncCursorPage[Message](data=[Message(id='msg_XSSp7FljwKfUJiFh3y8TlAAA', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="Both methods yield the same result, confirming the state with the most sightings and the number of sightings in that state.\n\n### Final Answer:\n\nThe state with the most sightings is **Washington** with **601** sightings.\n\n#### Explanation:\n- The dataset was analyzed to count the number of sightings in each state.\n- Two methods were used to ensure consistency:\n  1. Using the `value_counts` method to get the count of sightings in each state and identify the state with the highest count.\n  2. Using the `groupby` method to group the data by state, count the number of sightings in each state, and identify the state with the highest count.\n\nBoth methods provided the same result of Washington with 601 sightings.\n\n```python\n# Method 1: Using value_counts\nstate_sightings_counts = bigfoot_sightings['state'].value_counts()\nstate_with_most_sightings = state_sightings_counts.idxmax()\nmax_sightings_value_counts = state_sightings_counts.max()\n\n# Method 2: Using groupby and count\nstate_sightings_groupby = bigfoot_sightings.groupby('state').size()\nstate_with_most_sightings_groupby = state_sightings_groupby.idxmax()\nmax_sightings_groupby = state_sightings_groupby.max()\n```\n"), type='text')], created_at=1731716116, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_3AIztwG9ISw8a3FmaNlFjRR5', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_ULXDxiqgjJlvR9W3gIqHLzwy', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="First, I will determine which state has the most sightings by counting the occurrences of each state in the dataset. I will use two methods to confirm the consistency of the result.\n\n1. Using the `value_counts` method to count the occurrences of each state.\n2. Using the `groupby` method to group the data by state and count the number of sightings in each state.\n\nLet's perform these calculations."), type='text')], created_at=1731716110, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_3AIztwG9ISw8a3FmaNlFjRR5', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_A54ZsV4KOSFMgPk2g8DAy4uC', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='\n- **ALWAYS** before giving the Final Answer, try another method.\nThen reflect on the answers of the two methods you did and ask yourself\nif it answers correctly the original question.\nIf you are not sure, try another method.\n- If the methods tried do not give the same result,reflect and\ntry again until you have two methods that have the same result.\n- If you still cannot arrive to a consistent result, say that\nyou are not sure of the answer.\n- If you are sure of the correct answer, create a beautiful\nand thorough response using Markdown.\n- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,\nONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.\n- **ALWAYS**, as part of your "Final Answer", explain how you got\nto the answer on a section that starts with: "\n\nExplanation:\n".\nIn the explanation, mention the column names that you used to get\nto the final answer and provide the python code you used.\n\nWhich state has the most sightings? Provide the number of sightings in that state\n'), type='text')], created_at=1731716109, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_hTNTpBlEDW7OAeS5a4oxrKCG', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextCon ...
# Both methods yield the same result, confirming the state with the most sightings and the number of sightings in that state.
#
# ### Final Answer:
#
# The state with the most sightings is **Washington** with **601** sightings.
#
# #### Explanation:
# - The dataset was analyzed to count the number of sightings in each state.
# - Two methods were used to ensure consistency:
#   1. Using the `value_counts` method to get the count of sightings in each state and identify the state with the highest count.
#   2. Using the `groupby` method to group the data by state, count the number of sightings in each state, and identify the state with the highest count.
#
# Both methods provided the same result of Washington with 601 sightings.
#
# ```python
# # Method 1: Using value_counts
# state_sightings_counts = bigfoot_sightings['state'].value_counts()
# state_with_most_sightings = state_sightings_counts.idxmax()
# max_sightings_value_counts = state_sightings_counts.max()
#
# # Method 2: Using groupby and count
# state_sightings_groupby = bigfoot_sightings.groupby('state').size()
# state_with_most_sightings_groupby = state_sightings_groupby.idxmax()
# max_sightings_groupby = state_sightings_groupby.max()
# ```

# %%
user_question ="""Which season has the most sightings?
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)


content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# SyncCursorPage[Message](data=[Message(id='msg_HgL573vcdJTlf8ySNLvIelV4', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="Both methods yield the same result, confirming the season with the most sightings and the number of sightings in that season.\n\n### Final Answer:\n\nThe season with the most sightings is **Summer** with **1867** sightings.\n\n#### Explanation:\n- The dataset was analyzed to count the number of sightings in each season.\n- Two methods were used to ensure consistency:\n  1. Using the `value_counts` method to get the count of sightings in each season and identify the season with the highest count.\n  2. Using the `groupby` method to group the data by season, count the number of sightings in each season, and identify the season with the highest count.\n\nBoth methods provided the same result of Summer with 1867 sightings.\n\n```python\n# Method 1: Using value_counts\nseason_sightings_counts = bigfoot_sightings['season'].value_counts()\nseason_with_most_sightings = season_sightings_counts.idxmax()\nmax_sightings_season_value_counts = season_sightings_counts.max()\n\n# Method 2: Using groupby and count\nseason_sightings_groupby = bigfoot_sightings.groupby('season').size()\nseason_with_most_sightings_groupby = season_sightings_groupby.idxmax()\nmax_sightings_season_groupby = season_sightings_groupby.max()\n```"), type='text')], created_at=1731716156, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_ozootvVJy0zKq06vZxebhabj', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_ySxchGryhxqgNE2bVkf7Cnhb', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="First, I will determine which season has the most sightings by counting the occurrences of each season in the dataset. I will use two methods to confirm the consistency of the result:\n\n1. Using the `value_counts` method to count the occurrences of each season.\n2. Using the `groupby` method to group the data by season and count the number of sightings in each season.\n\nLet's perform these calculations."), type='text')], created_at=1731716150, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_ozootvVJy0zKq06vZxebhabj', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_SvERhrb77oQUByBa33BYJxlB', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='\n- **ALWAYS** before giving the Final Answer, try another method.\nThen reflect on the answers of the two methods you did and ask yourself\nif it answers correctly the original question.\nIf you are not sure, try another method.\n- If the methods tried do not give the same result,reflect and\ntry again until you have two methods that have the same result.\n- If you still cannot arrive to a consistent result, say that\nyou are not sure of the answer.\n- If you are sure of the correct answer, create a beautiful\nand thorough response using Markdown.\n- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,\nONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.\n- **ALWAYS**, as part of your "Final Answer", explain how you got\nto the answer on a section that starts with: "\n\nExplanation:\n".\nIn the explanation, mention the column names that you used to get\nto the final answer and provide the python code you used.\n\nWhich season has the most sightings?\n'), type='text')], created_at=1731716149, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_XSSp7FljwKfUJiFh3y8TlAAA', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text= ...
# Both methods yield the same result, confirming the season with the most sightings and the number of sightings in that season.
#
# ### Final Answer:
#
# The season with the most sightings is **Summer** with **1867** sightings.
#
# #### Explanation:
# - The dataset was analyzed to count the number of sightings in each season.
# - Two methods were used to ensure consistency:
#   1. Using the `value_counts` method to get the count of sightings in each season and identify the season with the highest count.
#   2. Using the `groupby` method to group the data by season, count the number of sightings in each season, and identify the season with the highest count.
#
# Both methods provided the same result of Summer with 1867 sightings.
#
# ```python
# # Method 1: Using value_counts
# season_sightings_counts = bigfoot_sightings['season'].value_counts()
# season_with_most_sightings = season_sightings_counts.idxmax()
# max_sightings_season_value_counts = season_sightings_counts.max()
#
# # Method 2: Using groupby and count
# season_sightings_groupby = bigfoot_sightings.groupby('season').size()
# season_with_most_sightings_groupby = season_sightings_groupby.idxmax()
# max_sightings_season_groupby = season_sightings_groupby.max()
# ```

# %%
user_question ="""What are the top 10 years with the most sightings? Use the date column and get the year there.
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)


content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# SyncCursorPage[Message](data=[Message(id='msg_bokKOTopjZ0xfs1lfq2b0im9', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="Both methods yield the same result, confirming the top 10 years with the most sightings and their respective counts.\n\n### Final Answer:\n\nThe top 10 years with the most sightings are as follows:\n\n| Year  | Sightings |\n|-------|-----------|\n| 2004  | 241       |\n| 2005  | 209       |\n| 2006  | 176       |\n| 2003  | 152       |\n| 2000  | 146       |\n| 2007  | 145       |\n| 2008  | 141       |\n| 2012  | 141       |\n| 2001  | 131       |\n| 2011  | 121       |\n\n#### Explanation:\n- The dataset's `date` column was converted to `datetime` format, and the year was extracted.\n- Two methods were used to ensure consistency:\n  1. Using the `value_counts` method to count the occurrences of each year and identify the top 10 years with the most sightings.\n  2. Using the `groupby` method to group the data by year, count the number of sightings in each year, and identify the top 10 years with the most sightings.\n\nBoth methods provided the same result for the top 10 years with the most sightings.\n\n```python\n# Extracting the year from the date column\nbigfoot_sightings['year'] = pd.to_datetime(bigfoot_sightings['date'], errors='coerce').dt.year\n\n# Method 1: Using value_counts\nyear_sightings_counts = bigfoot_sightings['year'].value_counts().nlargest(10)\n\n# Method 2: Using groupby and count\nyear_sightings_groupby = bigfoot_sightings.groupby('year').size().nlargest(10)\n```"), type='text')], created_at=1731716235, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_b20gcQbEkof4JlBOoQDFMH06', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_M3YHQPBvKmaq0Jx2RzL4iou1', assistant_id='asst_RwKsbjgYuiWwVY504iQbSFKQ', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="First, we'll extract the year from the `date` column and then determine the top 10 years with the most sightings. We'll use two methods to ensure consistency:\n\n1. Using the `value_counts` method to count the occurrences of each year.\n2. Using the `groupby` method to group the data by year and count the number of sightings in each year.\n\nLet's perform these calculations:"), type='text')], created_at=1731716230, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_b20gcQbEkof4JlBOoQDFMH06', status=None, thread_id='thread_pZ8V8taAeTRbhcrzVGx5iR6x'), Message(id='msg_Zv4yoe7BQZc2eObatR1QAjZJ', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='\n- **ALWAYS** before giving the Final Answer, try another method.\nThen reflect on the answers of the two methods you did and ask yourself\nif it answers correctly the original question.\nIf you are not sure, try another method.\n- If the methods tried do not give the same result,reflect and\ntry again until you have two methods that have the same result.\n- If you still cannot arrive to a consistent result, say that\nyou are not sure of the answer.\n- If you are sure of the correct answer, create a beautiful\nand thorough response using Markdown.\n- **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,\nONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.\n- **ALWAYS**, as part of your "Final Answer", explain how you got\nto the answer on a section that starts with: "\n\nExplanation:\n".\nIn the explanation, mention the column names that you used to get\nto the final answer and provide the python code you used.\n\nWhat are the top 10 years with the most sightings? Use the date column and get the year there.\n'), type='text')], created_at=1731716229, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, stat ...
# Both methods yield the same result, confirming the top 10 years with the most sightings and their respective counts.
#
# ### Final Answer:
#
# The top 10 years with the most sightings are as follows:
#
# | Year  | Sightings |
# |-------|-----------|
# | 2004  | 241       |
# | 2005  | 209       |
# | 2006  | 176       |
# | 2003  | 152       |
# | 2000  | 146       |
# | 2007  | 145       |
# | 2008  | 141       |
# | 2012  | 141       |
# | 2001  | 131       |
# | 2011  | 121       |
#
# #### Explanation:
# - The dataset's `date` column was converted to `datetime` format, and the year was extracted.
# - Two methods were used to ensure consistency:
#   1. Using the `value_counts` method to count the occurrences of each year and identify the top 10 years with the most sightings.
#   2. Using the `groupby` method to group the data by year, count the number of sightings in each year, and identify the top 10 years with the most sightings.
#
# Both methods provided the same result for the top 10 years with the most sightings.
#
# ```python
# # Extracting the year from the date column
# bigfoot_sightings['year'] = pd.to_datetime(bigfoot_sightings['date'], errors='coerce').dt.year
#
# # Method 1: Using value_counts
# year_sightings_counts = bigfoot_sightings['year'].value_counts().nlargest(10)
#
# # Method 2: Using groupby and count
# year_sightings_groupby = bigfoot_sightings.groupby('year').size().nlargest(10)
# ```

# %%
user_question ="""How many sightings did we have for Washington state in the year 2000?
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)


content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)
# Out:
# failed
# ### Mt. Mitchell Sighting in the Dataset
#
# There is one recorded Bigfoot sighting in the dataset which mentions Mt. Mitchell. Here are the details of that sighting:
#
# - **Observed:** "In early spring 1988, some friends of mine and I were hiking around Mt. Mitchell. We noticed deep impressions in the snow..."
# - **County:** Yancey County
# - **State:** North Carolina
# - **Season:** Spring
# - **Date:** March 15, 1988
# - **Classification:** Class B
#
# ### Explanation:
# To find out if there are any Bigfoot sightings observed at Mt. Mitchell, I checked for the occurrence of "Mt. Mitchell" in the "observed" column of the dataset. The steps taken are as follows:
#
# 1. Loaded the data and inspected the columns to understand its structure.
# 2. Filtered the dataset to locate rows where the "observed" column contains the text "Mt. Mitchell".
# 3. Verified the count and details of the sightings mentioning Mt. Mitchell.
#
# Here is the Python code used:
#
# ```python
# import pandas as pd
#
# # Load the dataframe from the uploaded file
# file_path = '/mnt/data/assistant-KTbs86aiQh7chrEjIa76W0aC'
# df = pd.read_csv(file_path)
#
# # Check for occurrences of 'Mt. Mitchell' in the 'observed' column
# mt_mitchell_sightings = df[df['observed'].str.contains('Mt. Mitchell', case=False, na=False)]
# mt_mitchell_sightings_count = mt_mitchell_sightings.shape[0]
#
# # Display the rows containing "Mt. Mitchell" in the "observed" column
# mt_mitchell_sightings
# ```
#
# Thus, there is a verified sighting observed at Mt. Mitchell mentioned in the data.

# %%
user_question ="""Using the "observed" column, are there any sightings observed at Mt. Mitchell?
"""

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content=PROMPT_SUFFIX + user_question
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )
if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  print(messages)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)

# Print the assistant response
content_block = messages.data[0].content[0]
value = content_block.text.value
print(value)

# %% [markdown]
# # Delete Assistant

# %%
response = client.beta.assistants.delete(assistant.id)
